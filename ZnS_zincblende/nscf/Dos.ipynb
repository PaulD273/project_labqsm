# %%
import numpy as np
import csv
import matplotlib.pyplot as plt
import read_dos_file

# %%
# %matplotlib widget

# %% [raw]
# highest occupied, lowest unoccupied level (ev):     4.7848    7.9267

# %%
gap = np.abs(4.7848  -  7.9267)
print(gap)
# Out:
# 3.1419000000000006

# %% [markdown]
# Experimental result obtained at almost 0 K, $E_{gap} \approx 3.434$ eV.  https://doi.org/10.1063/1.3253115

# %%
f=read_dos_file.read_dos_file('zns_025.dat')
print(f)
# Out:
# [[-1.0275e+01  9.3260e-07  9.3260e-09]
#  [-1.0265e+01  1.1260e-06  2.0590e-08]
#  [-1.0255e+01  1.3580e-06  3.4170e-08]
#  ...
#  [ 2.1635e+01  1.0600e-05  2.0000e+01]
#  [ 2.1645e+01  8.8630e-06  2.0000e+01]
#  [ 2.1655e+01  7.3970e-06  2.0000e+01]]

# %%
f1=read_dos_file.read_dos_file('zns_01.dat')
print(f1)
# Out:
# [[-9.6620e+00  5.8640e-07  5.8640e-09]
#  [-9.6520e+00  9.3720e-07  1.5240e-08]
#  [-9.6420e+00  1.4830e-06  3.0060e-08]
#  ...
#  [ 2.1018e+01  3.6590e-05  2.0000e+01]
#  [ 2.1028e+01  2.3890e-05  2.0000e+01]
#  [ 2.1038e+01  1.5430e-05  2.0000e+01]]

# %%
plt.scatter(f[:,0],f[:,1],marker=".", label='0.025 Ry')
plt.scatter(f1[:,0],f1[:,1],marker=".", label='0.01 Ry')
plt.xlabel(r"Energy [eV]")
plt.ylabel(r"DOS [#$e^{-}$/eV]")
plt.axvline(x=4.7848, linewidth=0.5, color='k', linestyle=(0, (8, 10)))
plt.axvline(x=7.9267, linewidth=0.5, color='k', linestyle=(0, (8, 10)))
plt.fill_between(f[:,0], 0, f[:,1], where=(f[:,0] < 6.206), facecolor='red', alpha=0.25)
plt.text(5.6, 1.5, 'Energy Gap', rotation=90)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
