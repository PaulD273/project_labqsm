# %% [markdown]
# # K-points convergence

# %%
import numpy as np
import csv
import matplotlib.pyplot as plt

# %%
def read_file(en_file):
    '''This function takes in a csv file, combs through it, stores its elements in a list which is eventually converted to a numpy array of floats'''
    data = []
    with open(en_file,'r') as file : 
        csv_reader = csv.reader(file, delimiter=',')
        for row in csv_reader:
            data.append(row)
            
        f=np.asarray(data, dtype='f8')
        
    return f

# %%
f = read_file('energy_nk.txt')
print(f)
# Out:
# [[-7.69304732  8.          0.23      ]
#  [-7.69806929 16.          0.36      ]
#  [-7.69833181 29.          0.75      ]
#  [-7.69855838 72.          1.7       ]]

# %%
plt.plot(f[:,1],f[:,0],marker="o")
plt.xlabel(r"IBZ k-points")
plt.ylabel(r"Convergent energy [Ry]")
#plt.legend()
# Out:
# Text(0, 0.5, 'Convergent energy [Ry]')

# %%
plt.plot(f[:,1],f[:,2],marker="o")
plt.ylabel(r"CPU time[s]")
plt.xlabel(r"IBZ k-points")
# Out:
# Text(0.5, 0, 'IBZ k-points')

# %% [markdown]
# ## Total energy difference between consecutive k-point grid runs

# %% [markdown]
# Total energy difference between $\mathbf{nk=4}$ and $\mathbf{nk=6}$:

# %%
E_46=f[0,0]-f[1,0]
print(E_46)
# Out:
# 0.005021970000000486

# %% [markdown]
# Total energy difference between $\mathbf{nk=6}$ and $\mathbf{nk=8}$:

# %%
E_68=f[1,0]-f[2,0]
print(E_68)
# Out:
# 0.00026251999999971076

# %% [markdown]
# Total energy difference between $\mathbf{nk=8}$ and $\mathbf{nk=12}$:

# %%
E_812=f[2,0]-f[3,0]
print(E_812)
# Out:
# 0.00022656999999970395

# %% [markdown]
# The difference between total energies becomes to flatten out. Increasing the spatial resolution in reciprocal space starts to bring little advantage while the computational cost almost doubled.
#
# $\mathbf{nk=8}$ was deemed as an appropriate grid spacing.
